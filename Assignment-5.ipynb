# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1st TASK (Regression)

# %%
df = pd.read_csv('weight-height.csv')

# %%
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
df.shape
# Out:
# (8555, 3)

# %%
df.describe()
# Out:
#             Height       Weight
# count  8555.000000  8555.000000
# mean     66.809925   165.632735
# std       3.851454    32.043922
# min      54.616858    65.780000
# 25%      63.957684   139.876803
# 50%      66.985923   168.521567
# 75%      69.604427   190.666305
# max      80.450000   269.989698

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8555 entries, 0 to 8554
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  8555 non-null   object
#  1   Height  8555 non-null   float64
#  2   Weight  8555 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 200.6+ KB

# %%
df.describe()
# Out:
#             Height       Weight
# count  8555.000000  8555.000000
# mean     66.809925   165.632735
# std       3.851454    32.043922
# min      54.616858    65.780000
# 25%      63.957684   139.876803
# 50%      66.985923   168.521567
# 75%      69.604427   190.666305
# max      80.450000   269.989698

# %%
df.isnull().sum()
# Out:
# Gender    0
# Height    0
# Weight    0
# dtype: int64

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
df.Gender = le.fit_transform(df.Gender)

# %%
df.head()
# Out:
#    Gender     Height      Weight
# 0       1  73.847017  241.893563
# 1       1  68.781904  162.310473
# 2       1  74.110105  212.740856
# 3       1  71.730978  220.042470
# 4       1  69.881796  206.349801

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
df['Height'] = scaler.fit_transform(df[['Height']])

# %%
df.head()
# Out:
#    Gender    Height      Weight
# 0       1  1.827233  241.893563
# 1       1  0.512039  162.310473
# 2       1  1.895545  212.740856
# 3       1  1.277788  220.042470
# 4       1  0.797634  206.349801

# %%
df['Weight'] = scaler.fit_transform(df[['Weight']])

# %%
df.head()
# Out:
#    Gender    Height    Weight
# 0       1  1.827233  2.380023
# 1       1  0.512039 -0.103684
# 2       1  1.895545  1.470197
# 3       1  1.277788  1.698073
# 4       1  0.797634  1.270738

# %%
x = df.drop('Weight', axis =1)

# %%
x.head()
# Out:
#    Gender    Height
# 0       1  1.827233
# 1       1  0.512039
# 2       1  1.895545
# 3       1  1.277788
# 4       1  0.797634

# %%
y = df[['Weight']]

# %%
y.head()
# Out:
#      Weight
# 0  2.380023
# 1 -0.103684
# 2  1.470197
# 3  1.698073
# 4  1.270738

# %%
from sklearn.model_selection import train_test_split as tts
from sklearn.linear_model import LinearRegression

# %%
xtrain, xtest, ytrain, ytext = tts(x,y,test_size = .30,random_state = 1)

# %%
xtrain.head()
# Out:
#       Gender    Height
# 1277       1  1.447687
# 5361       0 -1.518938
# 5728       0  0.599644
# 4276       1  0.379392
# 3112       1 -0.472192

# %%
xtrain.shape
# Out:
# (5988, 2)

# %%
xtest.shape
# Out:
# (2567, 2)

# %% [markdown]
# # Linear Regression

# %%
reg = LinearRegression().fit(xtrain, ytrain)

# %%
reg.coef_
# Out:
# array([[0.60369401, 0.71741679]])

# %%
reg.intercept_
# Out:
# array([-0.35595394])

# %%
predct = reg.predict(xtest)

# %%
predct
# Out:
# array([[-0.68043716],
#        [ 0.99561187],
#        [ 0.59304621],
#        ...,
#        [-0.15370062],
#        [ 0.66149925],
#        [ 1.11696722]])

# %%
df['predicted_result'] = reg.predict(x)

# %%
df.tail(10)
# Out:
#       Gender    Height    Weight  predicted_result
# 8545       0 -0.494707 -0.482541         -0.710865
# 8546       0  0.205744 -0.414072         -0.208349
# 8547       0 -1.959239 -1.505492         -1.761545
# 8548       0 -1.193126 -1.032317         -1.211923
# 8549       0 -1.337157 -1.393201         -1.315253
# 8550       0 -1.642587 -1.718593         -1.534373
# 8551       0 -0.879344 -1.114506         -0.986810
# 8552       0 -0.318306 -0.302417         -0.584312
# 8553       0  0.161000 -0.435501         -0.240450
# 8554       0 -1.528897 -1.072934         -1.452811

# %%
df.head()
# Out:
#    Gender    Height    Weight  predicted_result
# 0       1  1.827233  2.380023          1.558627
# 1       1  0.512039 -0.103684          0.615085
# 2       1  1.895545  1.470197          1.607636
# 3       1  1.277788  1.698073          1.164446
# 4       1  0.797634  1.270738          0.819976

# %%
reg.predict([[0,0.161000]])
# Out:
# array([[-0.24044984]])

# %%
reg.predict([[1,1.277788]])
# Out:
# array([[1.16444663]])

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
mse= mean_squared_error(ytext,predct)
accuracy = r2_score(ytext, predct)
mae= mean_absolute_error(ytext, predct)

# %%
mse
# Out:
# 0.09708113053084728

# %%
r2
# Out:
# 0.905995960709116

# %%
mae
# Out:
# 0.24911429687296716

# %% [markdown]
# # KNN Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
neigh = KNeighborsRegressor(n_neighbors=5)

# %%
neigh.fit(xtrain, ytrain)
# Out:
# KNeighborsRegressor()

# %%
K_predct = neigh.predict(xtest)

# %%
K_predct
# Out:
# array([[-0.48238561],
#        [ 0.99338323],
#        [ 0.41827163],
#        ...,
#        [-0.16760663],
#        [ 0.46881764],
#        [ 1.09018559]])

# %%
neigh.predict([[0,0.161000]])
# Out:
# array([[-0.1262495]])

# %%
neigh.predict([[1,1.277788]])
# Out:
# array([[1.05220251]])

# %%
mse1= mean_squared_error(ytext,K_predct)
accuracy1 = r2_score(ytext, K_predct)
mae1= mean_absolute_error(ytext, K_predct)

# %%
mse1
# Out:
# 0.11995179424647479

# %%
accuracy1
# Out:
# 0.8838502073708883

# %%
mae1
# Out:
# 0.27622290056368154

# %% [markdown]
# # 2nd TASK(Classification)

# %%
df1 = pd.read_csv("Breast Cancer.csv")

# %%
df1.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df1.shape
# Out:
# (569, 33)

# %%
df1.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df1.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
df1.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df1 = df1.drop('id',axis =1)

# %%
df1.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
df1.corr()
# Out:
#                          radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean                 1.000000      0.323782        0.997855   0.987357
# texture_mean                0.323782      1.000000        0.329533   0.321086
# perimeter_mean              0.997855      0.329533        1.000000   0.986507
# area_mean                   0.987357      0.321086        0.986507   1.000000
# smoothness_mean             0.170581     -0.023389        0.207278   0.177028
# compactness_mean            0.506124      0.236702        0.556936   0.498502
# concavity_mean              0.676764      0.302418        0.716136   0.685983
# concave points_mean         0.822529      0.293464        0.850977   0.823269
# symmetry_mean               0.147741      0.071401        0.183027   0.151293
# fractal_dimension_mean     -0.311631     -0.076437       -0.261477  -0.283110
# radius_se                   0.679090      0.275869        0.691765   0.732562
# ...

# %%
df1 = df1.drop('Unnamed: 32', axis =1)

# %%
df1.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
plt.figure(figsize= (25,15))
plt.title('Correlation for Every Column')
sns.heatmap(df1.corr(),annot= True)
# Out:
# <AxesSubplot:title={'center':'Correlation for Every Column'}>

# %%
x1= df1.drop('diagnosis', axis =1)

# %%
x1.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
y1 = df1[['diagnosis']]

# %%
y1.head()
# Out:
#   diagnosis
# 0         M
# 1         M
# 2         M
# 3         M
# 4         M

# %%
x1train, x1test, y1train, y1test = tts(x1,y1,test_size=.30,random_state = 1)

# %%
x1train.head()
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 249        11.52         14.93           73.87      406.3          0.10130
# 58         13.05         19.31           82.61      527.2          0.08060
# 476        14.20         20.53           92.41      618.4          0.08931
# 529        12.07         13.44           77.83      445.2          0.11000
# 422        11.61         16.02           75.46      408.2          0.10880
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 249           0.07808        0.043280             0.029290         0.1883
# 58            0.03789        0.000692             0.004167         0.1819
# 476           0.11080        0.050630             0.030580         0.1506
# 529           0.09009        0.037810             0.027980         0.1657
# 422           0.11680        0.070970             0.044970         0.1886
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# ...

# %%
x1train.shape
# Out:
# (398, 30)

# %%
x1test.shape
# Out:
# (171, 30)

# %%
##Decision Tree Classifier##

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix

# %%
clf = DecisionTreeClassifier()

# %%
clf.fit(x1train,y1train)
# Out:
# DecisionTreeClassifier()

# %%
pred1 = clf.predict(x1test)

# %%
pred1
# Out:
# array(['M', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'M',
#        'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'B',
#        'B', 'M', 'M', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'M',
#        'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B',
#        'B', 'M', 'B', 'M', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'B', 'B',
#        'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'M', 'M', 'B',
#        'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'M', 'M',
#        'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B',
#        'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M', 'M',
#        'B', 'B'], dtype=object)

# %%
y1test
# Out:
#     diagnosis
# 421         B
# 47          M
# 292         B
# 186         M
# 414         M
# ..        ...
# 6           M
# 487         M
# 11          M
# 268         B
# 419         B
#
# [171 rows x 1 columns]

# %%
np.array(y1test)
# Out:
# array([['B'],
#        ['M'],
#        ['B'],
#        ['M'],
#        ['M'],
#        ['M'],
#        ['M'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['B'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['M'],
#        ['M'],
#        ['M'],
#        ['B'],
#        ['M'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['B'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['M'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['M'],
# ...

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, roc_curve

# %%
print(classification_report(y1test, pred1))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.91      0.97      0.94       108
#            M       0.95      0.83      0.88        63
#
#     accuracy                           0.92       171
#    macro avg       0.93      0.90      0.91       171
# weighted avg       0.92      0.92      0.92       171

# %%
cm = confusion_matrix(y1test, pred1)

# %%
cm
# Out:
# array([[105,   3],
#        [ 11,  52]], dtype=int64)

# %%
sns.heatmap(cm, annot= True)
plt.xlabel('Predicted values')
plt.ylabel('Actual values')
plt.title('Confusin Matrix for Decision Tree Classifier')
# Out:
# Text(0.5, 1.0, 'Confusin Matrix for Decision Tree Classifier')

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(clf, x1test, y1test)
plt.plot([0,1],[0,1])

# %%
#Knn Classification ##

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh1 = KNeighborsClassifier(n_neighbors=5)

# %%
neigh1.fit(x1train,y1train)
# Out:
# KNeighborsClassifier()

# %%
pred2 = clf.predict(x1test)

# %%
pred2
# Out:
# array(['M', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'M',
#        'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'B',
#        'B', 'M', 'M', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'M',
#        'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B',
#        'B', 'M', 'B', 'M', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'B', 'B',
#        'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'M', 'M', 'B',
#        'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'M', 'M',
#        'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B',
#        'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M', 'M',
#        'B', 'B'], dtype=object)

# %%
y1test
# Out:
#     diagnosis
# 421         B
# 47          M
# 292         B
# 186         M
# 414         M
# ..        ...
# 6           M
# 487         M
# 11          M
# 268         B
# 419         B
#
# [171 rows x 1 columns]

# %%
print(classification_report(y1test, pred2))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.91      0.97      0.94       108
#            M       0.95      0.83      0.88        63
#
#     accuracy                           0.92       171
#    macro avg       0.93      0.90      0.91       171
# weighted avg       0.92      0.92      0.92       171

# %%
cm = confusion_matrix(y1test, pred1)

# %%
cm
# Out:
# array([[105,   3],
#        [ 11,  52]], dtype=int64)

# %%
sns.heatmap(cm, annot= True)
plt.xlabel('Predicted values')
plt.ylabel('Actual values')
plt.title('Confusin Matrix for Knn Classifier')
# Out:
# Text(0.5, 1.0, 'Confusin Matrix for Knn Classifier')

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(neigh1, x1test, y1test)
plt.plot([0,1],[0,1])
